# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.financial_eda import *

# %%
eda = FinancialEDA("../data/TSLA_historical_data.csv")

# %%
eda.plot_closing_prices("TSLA")

# %%
eda.daily_percentage_change()

# %%
eda.rolling_stats()
