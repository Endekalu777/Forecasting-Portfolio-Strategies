# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.data_handler import *

# %%
TSLA_handler = DataHandler("../data/TSLA_historical_data.csv")

# %%
TSLA_df = TSLA_handler.load_data()

# %%
TSLA_handler.detect_outliers()
# Out:
# Number of detected outliers: 21
# array([1, 1, 1, ..., 1, 1, 1])

# %%
TSLA_handler.handle_outliers()

# %%
TSLA_handler.plot_outliers()

# %%
TSLA_handler.process_data()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2014.000000  2014.000000  2014.000000  2014.000000  2014.000000
# mean     88.743650    90.735609    86.534925    88.662189    88.662189
# std     108.718116   111.222595   105.875776   108.557913   108.557913
# min       9.488000    10.331333     9.403333     9.578000     9.578000
# 25%      16.224167    16.458333    15.943500    16.217167    16.217167
# 50%      21.819667    22.206667    21.492333    21.881333    21.881333
# 75%     183.808338   186.592499   178.937500   182.904999   182.904999
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume   is_outlier
# count  2.014000e+03  2014.000000
# mean   1.033990e+08     0.979146
# std    5.489359e+07     0.203208
# min    1.062000e+07    -1.000000
# 25%    6.335325e+07     1.000000
# 50%    8.762100e+07     1.000000
# 75%    1.275895e+08     1.000000
# max    2.239438e+08     1.000000
# Open          0
# ...

# %%
TSLA_df = TSLA_handler.normalize_data()

# %%
TSLA_handler.save_scaler("../models/scaler.pkl")

# %%
TSLA_handler.save_processed_data("../data/cleaned_data_TSLA.csv")
