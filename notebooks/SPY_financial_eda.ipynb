# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.financial_eda import *

# %%
eda = FinancialEDA("../data/SPY_historical_data.csv")

# %%
eda.plot_closing_prices("SPY")

# %%
eda.daily_percentage_change()

# %%
eda.rolling_stats()

# %%
eda.trend_seasonality_decomposition()

# %%
eda.risk_metrics()
# Out:
# 95% Value at Risk (VaR): -0.01800241433113554
# Sharpe Ratio: 0.03212481689506961
