# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.data_handler import *

# %%
SPY_handler = DataHandler("../data/SPY_historical_data.csv")
SPY_df = SPY_handler.load_data()

# %%
SPY_handler.detect_outliers()
# Out:
# Number of detected outliers: 21

# %%
SPY_handler.handle_outliers()

# %%
SPY_handler.plot_outliers()

# %%
SPY_df = SPY_handler.normalize_data()

# %%
SPY_handler.save_processed_data("../data/cleaned_BND_data.csv")
