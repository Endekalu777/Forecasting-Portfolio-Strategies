# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.financial_eda import *

# %%
eda = FinancialEDA("../data/BND_historical_data.csv")

# %%
eda.plot_closing_prices("BND")

# %%
eda.daily_percentage_change()

# %%
eda.rolling_stats()

# %%
eda.trend_seasonality_decomposition()

# %%
eda.risk_metrics()
# Out:
# 95% Value at Risk (VaR): -0.00466574924365124
# Sharpe Ratio: -0.019534950696215553
