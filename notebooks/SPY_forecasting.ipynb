# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.forecast import *

# %%
analyzer = MarketTrendAnalyzer("../models/lstm_model_SPY_historical_data.h5", "../models/SPY_scaler.pkl", "../data/SPY_historical_data.csv")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# LSTM model successfully loaded from ../models/lstm_model_SPY_historical_data.h5
# Scaler successfully loaded from ../models/SPY_scaler.pkl

# %%
forecast_df = analyzer.generate_forecast("../data/forecasted_SPY_data.csv")
# Out:
# Forecast saved to ../data/forecasted_SPY_data.csv

# %%
analyzer.plot_forecast()

# %%
analyzer.analyze_trends()
# Out:
# {'Trend': 'Upward',
#  'Trend_Magnitude': 3.4179650247097015,
#  'Volatility': 0.00038477892,
#  'Max_Price': 393.7573,
#  'Min_Price': 377.41196,
#  'Price_Range': 16.345337}

# %%
analyzer.generate_report()
# Out:
# '\n        Market Trend Analysis Report\n        ============================\n\n        1. Overall Trend Analysis:\n        -------------------------\n        Direction: Upward\n        Trend Magnitude: 3.42\n\n        2. Price Projections:\n        --------------------\n        Forecasted Maximum Price: $393.76\n        Forecasted Minimum Price: $377.41\n        Expected Price Range: $16.35\n\n        3. Volatility Analysis:\n        ----------------------\n        Forecasted Volatility: 0.04%\n\n        4. Market Opportunities and Risks:\n        -------------------------------\n        Main Opportunities:\n        * Price appreciation potential\n        * Stable price movement expected\n\n        Main Risks:\n        * Limited price movement\n        * Overvaluation risk\n\n        5. Investment Implications:\n        ------------------------\n        Suitable for longer-term position holding\n        '
