# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.forecast import *

# %%
analyzer = MarketTrendAnalyzer("../models/lstm_model_TSLA_historical_data.h5", "../models/TSLA_scaler.pkl", "../data/TSLA_historical_data.csv")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# LSTM model successfully loaded from ../models/lstm_model_TSLA_historical_data.h5
# Scaler successfully loaded from ../models/TSLA_scaler.pkl

# %%
forecast_df = analyzer.generate_forecast("../data/forecasted_TSLA_data.csv")
# Out:
# Forecast saved to ../data/forecasted_TSLA_data.csv

# %%
analyzer.plot_forecast()

# %%
analyzer.analyze_trends()
# Out:
# {'Trend': 'Upward',
#  'Trend_Magnitude': 5.012085661292076,
#  'Volatility': 0.00068407616,
#  'Max_Price': 130.4334,
#  'Min_Price': 123.21801,
#  'Price_Range': 7.2153854}

# %%
analyzer.generate_report()
# Out:
# '\n        Market Trend Analysis Report\n        ============================\n\n        1. Overall Trend Analysis:\n        -------------------------\n        Direction: Upward\n        Trend Magnitude: 5.01\n\n        2. Price Projections:\n        --------------------\n        Forecasted Maximum Price: $130.43\n        Forecasted Minimum Price: $123.22\n        Expected Price Range: $7.22\n\n        3. Volatility Analysis:\n        ----------------------\n        Forecasted Volatility: 0.07%\n\n        4. Market Opportunities and Risks:\n        -------------------------------\n        Main Opportunities:\n        * Price appreciation potential\n        * Stable price movement expected\n\n        Main Risks:\n        * Limited price movement\n        * Overvaluation risk\n\n        5. Investment Implications:\n        ------------------------\n        Suitable for longer-term position holding\n        '
