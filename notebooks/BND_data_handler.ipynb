# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.data_handler import *

# %%
BND_handler = DataHandler("../data/BND_historical_data.csv")
BND_df = BND_handler.load_data()

# %%
BND_handler.process_data()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2014.000000  2014.000000  2014.000000  2014.000000  2014.000000
# mean     82.119682    82.225814    82.002612    82.115015    70.047949
# std       3.744186     3.726866     3.753981     3.740979     5.329671
# min      69.139999    69.580002    69.089996    69.379997    62.637539
# 25%      80.447502    80.532499    80.244999    80.430000    65.995964
# 50%      82.035000    82.139999    81.930000    82.029999    67.568283
# 75%      84.570000    84.709999    84.465000    84.622498    75.097782
# max      89.550003    89.589996    89.440002    89.480003    79.812935
#
#              Volume
# count  2.014000e+03
# mean   3.705960e+06
# std    2.488405e+06
# min    0.000000e+00
# 25%    1.843650e+06
# 50%    2.905900e+06
# 75%    5.016900e+06
# max    2.479270e+07
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Number of detected outliers: 21

# %%
BND_df = BND_handler.normalize_data()

# %%
BND_handler.save_processed_data("../data/cleaned_BND_data.csv")
